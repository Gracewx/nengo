# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1198945732" href="javascript:toggle_input_1198945732()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1198945732;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1198945732 = document.getElementById("1198945732");
#                 var cell = link_1198945732;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1198945732;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1198945732 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1198945732 = cell.previousElementSibling;
#                 }
#                 input_1198945732.style.display = "none"; // hide
#
#                 toggle_input_1198945732 = function() {
#                     if (input_1198945732.style.display == "none") {
#                         input_1198945732.style.display = ""; // show
#                         link_1198945732.innerHTML = "Hide Input";
#                     } else {
#                         input_1198945732.style.display = "none"; // hide
#                         link_1198945732.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1198945732 = $("a[id='1198945732']");
#                 var cell_1198945732 = link_1198945732.parents("div.cell:first");
#                 if (cell_1198945732.length == 0) {
#                     cell_1198945732 = link_1198945732.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1198945732 = cell_1198945732.children("div.input");
#                 if (input_1198945732.length == 0) {
#                     input_1198945732 = cell_1198945732.prev("div.nbinput");
#                 }
#                 input_1198945732.hide();
#
#                 toggle_input_1198945732 = function() {
#                     if (input_1198945732.is(':hidden')) {
#                         input_1198945732.slideDown();
#                         link_1198945732[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1198945732.slideUp();
#                         link_1198945732[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1953298051" href="javascript:toggle_input_1953298051()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1953298051;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1953298051 = document.getElementById("1953298051");
#                 var cell = link_1953298051;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1953298051;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1953298051 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1953298051 = cell.previousElementSibling;
#                 }
#                 input_1953298051.style.display = "none"; // hide
#
#                 toggle_input_1953298051 = function() {
#                     if (input_1953298051.style.display == "none") {
#                         input_1953298051.style.display = ""; // show
#                         link_1953298051.innerHTML = "Hide Input";
#                     } else {
#                         input_1953298051.style.display = "none"; // hide
#                         link_1953298051.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1953298051 = $("a[id='1953298051']");
#                 var cell_1953298051 = link_1953298051.parents("div.cell:first");
#                 if (cell_1953298051.length == 0) {
#                     cell_1953298051 = link_1953298051.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1953298051 = cell_1953298051.children("div.input");
#                 if (input_1953298051.length == 0) {
#                     input_1953298051 = cell_1953298051.prev("div.nbinput");
#                 }
#                 input_1953298051.hide();
#
#                 toggle_input_1953298051 = function() {
#                     if (input_1953298051.is(':hidden')) {
#                         input_1953298051.slideDown();
#                         link_1953298051[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1953298051.slideUp();
#                         link_1953298051[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="2112639237" href="javascript:toggle_input_2112639237()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2112639237;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2112639237 = document.getElementById("2112639237");
#                 var cell = link_2112639237;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2112639237;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2112639237 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2112639237 = cell.previousElementSibling;
#                 }
#                 input_2112639237.style.display = "none"; // hide
#
#                 toggle_input_2112639237 = function() {
#                     if (input_2112639237.style.display == "none") {
#                         input_2112639237.style.display = ""; // show
#                         link_2112639237.innerHTML = "Hide Input";
#                     } else {
#                         input_2112639237.style.display = "none"; // hide
#                         link_2112639237.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2112639237 = $("a[id='2112639237']");
#                 var cell_2112639237 = link_2112639237.parents("div.cell:first");
#                 if (cell_2112639237.length == 0) {
#                     cell_2112639237 = link_2112639237.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2112639237 = cell_2112639237.children("div.input");
#                 if (input_2112639237.length == 0) {
#                     input_2112639237 = cell_2112639237.prev("div.nbinput");
#                 }
#                 input_2112639237.hide();
#
#                 toggle_input_2112639237 = function() {
#                     if (input_2112639237.is(':hidden')) {
#                         input_2112639237.slideDown();
#                         link_2112639237[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2112639237.slideUp();
#                         link_2112639237[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="1701106728" href="javascript:toggle_input_1701106728()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1701106728;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1701106728 = document.getElementById("1701106728");
#                 var cell = link_1701106728;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1701106728;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1701106728 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1701106728 = cell.previousElementSibling;
#                 }
#                 input_1701106728.style.display = "none"; // hide
#
#                 toggle_input_1701106728 = function() {
#                     if (input_1701106728.style.display == "none") {
#                         input_1701106728.style.display = ""; // show
#                         link_1701106728.innerHTML = "Hide Input";
#                     } else {
#                         input_1701106728.style.display = "none"; // hide
#                         link_1701106728.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1701106728 = $("a[id='1701106728']");
#                 var cell_1701106728 = link_1701106728.parents("div.cell:first");
#                 if (cell_1701106728.length == 0) {
#                     cell_1701106728 = link_1701106728.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1701106728 = cell_1701106728.children("div.input");
#                 if (input_1701106728.length == 0) {
#                     input_1701106728 = cell_1701106728.prev("div.nbinput");
#                 }
#                 input_1701106728.hide();
#
#                 toggle_input_1701106728 = function() {
#                     if (input_1701106728.is(':hidden')) {
#                         input_1701106728.slideDown();
#                         link_1701106728[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1701106728.slideUp();
#                         link_1701106728[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="1135086364" href="javascript:toggle_input_1135086364()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1135086364;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1135086364 = document.getElementById("1135086364");
#                 var cell = link_1135086364;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1135086364;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1135086364 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1135086364 = cell.previousElementSibling;
#                 }
#                 input_1135086364.style.display = "none"; // hide
#
#                 toggle_input_1135086364 = function() {
#                     if (input_1135086364.style.display == "none") {
#                         input_1135086364.style.display = ""; // show
#                         link_1135086364.innerHTML = "Hide Input";
#                     } else {
#                         input_1135086364.style.display = "none"; // hide
#                         link_1135086364.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1135086364 = $("a[id='1135086364']");
#                 var cell_1135086364 = link_1135086364.parents("div.cell:first");
#                 if (cell_1135086364.length == 0) {
#                     cell_1135086364 = link_1135086364.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1135086364 = cell_1135086364.children("div.input");
#                 if (input_1135086364.length == 0) {
#                     input_1135086364 = cell_1135086364.prev("div.nbinput");
#                 }
#                 input_1135086364.hide();
#
#                 toggle_input_1135086364 = function() {
#                     if (input_1135086364.is(':hidden')) {
#                         input_1135086364.slideDown();
#                         link_1135086364[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1135086364.slideUp();
#                         link_1135086364[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1348860622" href="javascript:toggle_input_1348860622()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1348860622;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1348860622 = document.getElementById("1348860622");
#                 var cell = link_1348860622;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1348860622;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1348860622 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1348860622 = cell.previousElementSibling;
#                 }
#                 input_1348860622.style.display = "none"; // hide
#
#                 toggle_input_1348860622 = function() {
#                     if (input_1348860622.style.display == "none") {
#                         input_1348860622.style.display = ""; // show
#                         link_1348860622.innerHTML = "Hide Input";
#                     } else {
#                         input_1348860622.style.display = "none"; // hide
#                         link_1348860622.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1348860622 = $("a[id='1348860622']");
#                 var cell_1348860622 = link_1348860622.parents("div.cell:first");
#                 if (cell_1348860622.length == 0) {
#                     cell_1348860622 = link_1348860622.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1348860622 = cell_1348860622.children("div.input");
#                 if (input_1348860622.length == 0) {
#                     input_1348860622 = cell_1348860622.prev("div.nbinput");
#                 }
#                 input_1348860622.hide();
#
#                 toggle_input_1348860622 = function() {
#                     if (input_1348860622.is(':hidden')) {
#                         input_1348860622.slideDown();
#                         link_1348860622[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1348860622.slideUp();
#                         link_1348860622[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="283314348" href="javascript:toggle_input_283314348()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_283314348;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_283314348 = document.getElementById("283314348");
#                 var cell = link_283314348;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_283314348;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_283314348 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_283314348 = cell.previousElementSibling;
#                 }
#                 input_283314348.style.display = "none"; // hide
#
#                 toggle_input_283314348 = function() {
#                     if (input_283314348.style.display == "none") {
#                         input_283314348.style.display = ""; // show
#                         link_283314348.innerHTML = "Hide Input";
#                     } else {
#                         input_283314348.style.display = "none"; // hide
#                         link_283314348.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_283314348 = $("a[id='283314348']");
#                 var cell_283314348 = link_283314348.parents("div.cell:first");
#                 if (cell_283314348.length == 0) {
#                     cell_283314348 = link_283314348.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_283314348 = cell_283314348.children("div.input");
#                 if (input_283314348.length == 0) {
#                     input_283314348 = cell_283314348.prev("div.nbinput");
#                 }
#                 input_283314348.hide();
#
#                 toggle_input_283314348 = function() {
#                     if (input_283314348.is(':hidden')) {
#                         input_283314348.slideDown();
#                         link_283314348[0].innerHTML = "Hide Input";
#                     } else {
#                         input_283314348.slideUp();
#                         link_283314348[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="841152437" href="javascript:toggle_input_841152437()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_841152437;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_841152437 = document.getElementById("841152437");
#                 var cell = link_841152437;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_841152437;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_841152437 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_841152437 = cell.previousElementSibling;
#                 }
#                 input_841152437.style.display = "none"; // hide
#
#                 toggle_input_841152437 = function() {
#                     if (input_841152437.style.display == "none") {
#                         input_841152437.style.display = ""; // show
#                         link_841152437.innerHTML = "Hide Input";
#                     } else {
#                         input_841152437.style.display = "none"; // hide
#                         link_841152437.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_841152437 = $("a[id='841152437']");
#                 var cell_841152437 = link_841152437.parents("div.cell:first");
#                 if (cell_841152437.length == 0) {
#                     cell_841152437 = link_841152437.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_841152437 = cell_841152437.children("div.input");
#                 if (input_841152437.length == 0) {
#                     input_841152437 = cell_841152437.prev("div.nbinput");
#                 }
#                 input_841152437.hide();
#
#                 toggle_input_841152437 = function() {
#                     if (input_841152437.is(':hidden')) {
#                         input_841152437.slideDown();
#                         link_841152437[0].innerHTML = "Hide Input";
#                     } else {
#                         input_841152437.slideUp();
#                         link_841152437[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="34571694" href="javascript:toggle_input_34571694()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_34571694;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_34571694 = document.getElementById("34571694");
#                 var cell = link_34571694;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_34571694;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_34571694 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_34571694 = cell.previousElementSibling;
#                 }
#                 input_34571694.style.display = "none"; // hide
#
#                 toggle_input_34571694 = function() {
#                     if (input_34571694.style.display == "none") {
#                         input_34571694.style.display = ""; // show
#                         link_34571694.innerHTML = "Hide Input";
#                     } else {
#                         input_34571694.style.display = "none"; // hide
#                         link_34571694.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_34571694 = $("a[id='34571694']");
#                 var cell_34571694 = link_34571694.parents("div.cell:first");
#                 if (cell_34571694.length == 0) {
#                     cell_34571694 = link_34571694.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_34571694 = cell_34571694.children("div.input");
#                 if (input_34571694.length == 0) {
#                     input_34571694 = cell_34571694.prev("div.nbinput");
#                 }
#                 input_34571694.hide();
#
#                 toggle_input_34571694 = function() {
#                     if (input_34571694.is(':hidden')) {
#                         input_34571694.slideDown();
#                         link_34571694[0].innerHTML = "Hide Input";
#                     } else {
#                         input_34571694.slideUp();
#                         link_34571694[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1788455963" href="javascript:toggle_input_1788455963()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1788455963;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1788455963 = document.getElementById("1788455963");
#                 var cell = link_1788455963;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1788455963;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1788455963 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1788455963 = cell.previousElementSibling;
#                 }
#                 input_1788455963.style.display = "none"; // hide
#
#                 toggle_input_1788455963 = function() {
#                     if (input_1788455963.style.display == "none") {
#                         input_1788455963.style.display = ""; // show
#                         link_1788455963.innerHTML = "Hide Input";
#                     } else {
#                         input_1788455963.style.display = "none"; // hide
#                         link_1788455963.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1788455963 = $("a[id='1788455963']");
#                 var cell_1788455963 = link_1788455963.parents("div.cell:first");
#                 if (cell_1788455963.length == 0) {
#                     cell_1788455963 = link_1788455963.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1788455963 = cell_1788455963.children("div.input");
#                 if (input_1788455963.length == 0) {
#                     input_1788455963 = cell_1788455963.prev("div.nbinput");
#                 }
#                 input_1788455963.hide();
#
#                 toggle_input_1788455963 = function() {
#                     if (input_1788455963.is(':hidden')) {
#                         input_1788455963.slideDown();
#                         link_1788455963[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1788455963.slideUp();
#                         link_1788455963[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1827347406" href="javascript:toggle_input_1827347406()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1827347406;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1827347406 = document.getElementById("1827347406");
#                 var cell = link_1827347406;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1827347406;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1827347406 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1827347406 = cell.previousElementSibling;
#                 }
#                 input_1827347406.style.display = "none"; // hide
#
#                 toggle_input_1827347406 = function() {
#                     if (input_1827347406.style.display == "none") {
#                         input_1827347406.style.display = ""; // show
#                         link_1827347406.innerHTML = "Hide Input";
#                     } else {
#                         input_1827347406.style.display = "none"; // hide
#                         link_1827347406.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1827347406 = $("a[id='1827347406']");
#                 var cell_1827347406 = link_1827347406.parents("div.cell:first");
#                 if (cell_1827347406.length == 0) {
#                     cell_1827347406 = link_1827347406.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1827347406 = cell_1827347406.children("div.input");
#                 if (input_1827347406.length == 0) {
#                     input_1827347406 = cell_1827347406.prev("div.nbinput");
#                 }
#                 input_1827347406.hide();
#
#                 toggle_input_1827347406 = function() {
#                     if (input_1827347406.is(':hidden')) {
#                         input_1827347406.slideDown();
#                         link_1827347406[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1827347406.slideUp();
#                         link_1827347406[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="573756171" href="javascript:toggle_input_573756171()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_573756171;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_573756171 = document.getElementById("573756171");
#                 var cell = link_573756171;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_573756171;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_573756171 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_573756171 = cell.previousElementSibling;
#                 }
#                 input_573756171.style.display = "none"; // hide
#
#                 toggle_input_573756171 = function() {
#                     if (input_573756171.style.display == "none") {
#                         input_573756171.style.display = ""; // show
#                         link_573756171.innerHTML = "Hide Input";
#                     } else {
#                         input_573756171.style.display = "none"; // hide
#                         link_573756171.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_573756171 = $("a[id='573756171']");
#                 var cell_573756171 = link_573756171.parents("div.cell:first");
#                 if (cell_573756171.length == 0) {
#                     cell_573756171 = link_573756171.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_573756171 = cell_573756171.children("div.input");
#                 if (input_573756171.length == 0) {
#                     input_573756171 = cell_573756171.prev("div.nbinput");
#                 }
#                 input_573756171.hide();
#
#                 toggle_input_573756171 = function() {
#                     if (input_573756171.is(':hidden')) {
#                         input_573756171.slideDown();
#                         link_573756171[0].innerHTML = "Hide Input";
#                     } else {
#                         input_573756171.slideUp();
#                         link_573756171[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="1161910443" href="javascript:toggle_input_1161910443()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1161910443;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1161910443 = document.getElementById("1161910443");
#                 var cell = link_1161910443;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1161910443;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1161910443 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1161910443 = cell.previousElementSibling;
#                 }
#                 input_1161910443.style.display = "none"; // hide
#
#                 toggle_input_1161910443 = function() {
#                     if (input_1161910443.style.display == "none") {
#                         input_1161910443.style.display = ""; // show
#                         link_1161910443.innerHTML = "Hide Input";
#                     } else {
#                         input_1161910443.style.display = "none"; // hide
#                         link_1161910443.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1161910443 = $("a[id='1161910443']");
#                 var cell_1161910443 = link_1161910443.parents("div.cell:first");
#                 if (cell_1161910443.length == 0) {
#                     cell_1161910443 = link_1161910443.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1161910443 = cell_1161910443.children("div.input");
#                 if (input_1161910443.length == 0) {
#                     input_1161910443 = cell_1161910443.prev("div.nbinput");
#                 }
#                 input_1161910443.hide();
#
#                 toggle_input_1161910443 = function() {
#                     if (input_1161910443.is(':hidden')) {
#                         input_1161910443.slideDown();
#                         link_1161910443[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1161910443.slideUp();
#                         link_1161910443[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
