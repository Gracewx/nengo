# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1764307937" href="javascript:toggle_input_1764307937()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1764307937;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1764307937 = document.getElementById("1764307937");
#                 var cell = link_1764307937;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1764307937;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1764307937 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1764307937 = cell.previousElementSibling;
#                 }
#                 input_1764307937.style.display = "none"; // hide
#
#                 toggle_input_1764307937 = function() {
#                     if (input_1764307937.style.display == "none") {
#                         input_1764307937.style.display = ""; // show
#                         link_1764307937.innerHTML = "Hide Input";
#                     } else {
#                         input_1764307937.style.display = "none"; // hide
#                         link_1764307937.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1764307937 = $("a[id='1764307937']");
#                 var cell_1764307937 = link_1764307937.parents("div.cell:first");
#                 if (cell_1764307937.length == 0) {
#                     cell_1764307937 = link_1764307937.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1764307937 = cell_1764307937.children("div.input");
#                 if (input_1764307937.length == 0) {
#                     input_1764307937 = cell_1764307937.prev("div.nbinput");
#                 }
#                 input_1764307937.hide();
#
#                 toggle_input_1764307937 = function() {
#                     if (input_1764307937.is(':hidden')) {
#                         input_1764307937.slideDown();
#                         link_1764307937[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1764307937.slideUp();
#                         link_1764307937[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="279264733" href="javascript:toggle_input_279264733()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_279264733;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_279264733 = document.getElementById("279264733");
#                 var cell = link_279264733;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_279264733;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_279264733 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_279264733 = cell.previousElementSibling;
#                 }
#                 input_279264733.style.display = "none"; // hide
#
#                 toggle_input_279264733 = function() {
#                     if (input_279264733.style.display == "none") {
#                         input_279264733.style.display = ""; // show
#                         link_279264733.innerHTML = "Hide Input";
#                     } else {
#                         input_279264733.style.display = "none"; // hide
#                         link_279264733.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_279264733 = $("a[id='279264733']");
#                 var cell_279264733 = link_279264733.parents("div.cell:first");
#                 if (cell_279264733.length == 0) {
#                     cell_279264733 = link_279264733.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_279264733 = cell_279264733.children("div.input");
#                 if (input_279264733.length == 0) {
#                     input_279264733 = cell_279264733.prev("div.nbinput");
#                 }
#                 input_279264733.hide();
#
#                 toggle_input_279264733 = function() {
#                     if (input_279264733.is(':hidden')) {
#                         input_279264733.slideDown();
#                         link_279264733[0].innerHTML = "Hide Input";
#                     } else {
#                         input_279264733.slideUp();
#                         link_279264733[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="1054926601" href="javascript:toggle_input_1054926601()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1054926601;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1054926601 = document.getElementById("1054926601");
#                 var cell = link_1054926601;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1054926601;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1054926601 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1054926601 = cell.previousElementSibling;
#                 }
#                 input_1054926601.style.display = "none"; // hide
#
#                 toggle_input_1054926601 = function() {
#                     if (input_1054926601.style.display == "none") {
#                         input_1054926601.style.display = ""; // show
#                         link_1054926601.innerHTML = "Hide Input";
#                     } else {
#                         input_1054926601.style.display = "none"; // hide
#                         link_1054926601.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1054926601 = $("a[id='1054926601']");
#                 var cell_1054926601 = link_1054926601.parents("div.cell:first");
#                 if (cell_1054926601.length == 0) {
#                     cell_1054926601 = link_1054926601.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1054926601 = cell_1054926601.children("div.input");
#                 if (input_1054926601.length == 0) {
#                     input_1054926601 = cell_1054926601.prev("div.nbinput");
#                 }
#                 input_1054926601.hide();
#
#                 toggle_input_1054926601 = function() {
#                     if (input_1054926601.is(':hidden')) {
#                         input_1054926601.slideDown();
#                         link_1054926601[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1054926601.slideUp();
#                         link_1054926601[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="1789011924" href="javascript:toggle_input_1789011924()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1789011924;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1789011924 = document.getElementById("1789011924");
#                 var cell = link_1789011924;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1789011924;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1789011924 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1789011924 = cell.previousElementSibling;
#                 }
#                 input_1789011924.style.display = "none"; // hide
#
#                 toggle_input_1789011924 = function() {
#                     if (input_1789011924.style.display == "none") {
#                         input_1789011924.style.display = ""; // show
#                         link_1789011924.innerHTML = "Hide Input";
#                     } else {
#                         input_1789011924.style.display = "none"; // hide
#                         link_1789011924.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1789011924 = $("a[id='1789011924']");
#                 var cell_1789011924 = link_1789011924.parents("div.cell:first");
#                 if (cell_1789011924.length == 0) {
#                     cell_1789011924 = link_1789011924.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1789011924 = cell_1789011924.children("div.input");
#                 if (input_1789011924.length == 0) {
#                     input_1789011924 = cell_1789011924.prev("div.nbinput");
#                 }
#                 input_1789011924.hide();
#
#                 toggle_input_1789011924 = function() {
#                     if (input_1789011924.is(':hidden')) {
#                         input_1789011924.slideDown();
#                         link_1789011924[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1789011924.slideUp();
#                         link_1789011924[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="2011423306" href="javascript:toggle_input_2011423306()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2011423306;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2011423306 = document.getElementById("2011423306");
#                 var cell = link_2011423306;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2011423306;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2011423306 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2011423306 = cell.previousElementSibling;
#                 }
#                 input_2011423306.style.display = "none"; // hide
#
#                 toggle_input_2011423306 = function() {
#                     if (input_2011423306.style.display == "none") {
#                         input_2011423306.style.display = ""; // show
#                         link_2011423306.innerHTML = "Hide Input";
#                     } else {
#                         input_2011423306.style.display = "none"; // hide
#                         link_2011423306.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2011423306 = $("a[id='2011423306']");
#                 var cell_2011423306 = link_2011423306.parents("div.cell:first");
#                 if (cell_2011423306.length == 0) {
#                     cell_2011423306 = link_2011423306.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2011423306 = cell_2011423306.children("div.input");
#                 if (input_2011423306.length == 0) {
#                     input_2011423306 = cell_2011423306.prev("div.nbinput");
#                 }
#                 input_2011423306.hide();
#
#                 toggle_input_2011423306 = function() {
#                     if (input_2011423306.is(':hidden')) {
#                         input_2011423306.slideDown();
#                         link_2011423306[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2011423306.slideUp();
#                         link_2011423306[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="34774209" href="javascript:toggle_input_34774209()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_34774209;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_34774209 = document.getElementById("34774209");
#                 var cell = link_34774209;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_34774209;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_34774209 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_34774209 = cell.previousElementSibling;
#                 }
#                 input_34774209.style.display = "none"; // hide
#
#                 toggle_input_34774209 = function() {
#                     if (input_34774209.style.display == "none") {
#                         input_34774209.style.display = ""; // show
#                         link_34774209.innerHTML = "Hide Input";
#                     } else {
#                         input_34774209.style.display = "none"; // hide
#                         link_34774209.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_34774209 = $("a[id='34774209']");
#                 var cell_34774209 = link_34774209.parents("div.cell:first");
#                 if (cell_34774209.length == 0) {
#                     cell_34774209 = link_34774209.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_34774209 = cell_34774209.children("div.input");
#                 if (input_34774209.length == 0) {
#                     input_34774209 = cell_34774209.prev("div.nbinput");
#                 }
#                 input_34774209.hide();
#
#                 toggle_input_34774209 = function() {
#                     if (input_34774209.is(':hidden')) {
#                         input_34774209.slideDown();
#                         link_34774209[0].innerHTML = "Hide Input";
#                     } else {
#                         input_34774209.slideUp();
#                         link_34774209[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="6873476" href="javascript:toggle_input_6873476()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_6873476;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_6873476 = document.getElementById("6873476");
#                 var cell = link_6873476;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_6873476;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_6873476 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_6873476 = cell.previousElementSibling;
#                 }
#                 input_6873476.style.display = "none"; // hide
#
#                 toggle_input_6873476 = function() {
#                     if (input_6873476.style.display == "none") {
#                         input_6873476.style.display = ""; // show
#                         link_6873476.innerHTML = "Hide Input";
#                     } else {
#                         input_6873476.style.display = "none"; // hide
#                         link_6873476.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_6873476 = $("a[id='6873476']");
#                 var cell_6873476 = link_6873476.parents("div.cell:first");
#                 if (cell_6873476.length == 0) {
#                     cell_6873476 = link_6873476.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_6873476 = cell_6873476.children("div.input");
#                 if (input_6873476.length == 0) {
#                     input_6873476 = cell_6873476.prev("div.nbinput");
#                 }
#                 input_6873476.hide();
#
#                 toggle_input_6873476 = function() {
#                     if (input_6873476.is(':hidden')) {
#                         input_6873476.slideDown();
#                         link_6873476[0].innerHTML = "Hide Input";
#                     } else {
#                         input_6873476.slideUp();
#                         link_6873476[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="334704298" href="javascript:toggle_input_334704298()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_334704298;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_334704298 = document.getElementById("334704298");
#                 var cell = link_334704298;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_334704298;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_334704298 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_334704298 = cell.previousElementSibling;
#                 }
#                 input_334704298.style.display = "none"; // hide
#
#                 toggle_input_334704298 = function() {
#                     if (input_334704298.style.display == "none") {
#                         input_334704298.style.display = ""; // show
#                         link_334704298.innerHTML = "Hide Input";
#                     } else {
#                         input_334704298.style.display = "none"; // hide
#                         link_334704298.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_334704298 = $("a[id='334704298']");
#                 var cell_334704298 = link_334704298.parents("div.cell:first");
#                 if (cell_334704298.length == 0) {
#                     cell_334704298 = link_334704298.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_334704298 = cell_334704298.children("div.input");
#                 if (input_334704298.length == 0) {
#                     input_334704298 = cell_334704298.prev("div.nbinput");
#                 }
#                 input_334704298.hide();
#
#                 toggle_input_334704298 = function() {
#                     if (input_334704298.is(':hidden')) {
#                         input_334704298.slideDown();
#                         link_334704298[0].innerHTML = "Hide Input";
#                     } else {
#                         input_334704298.slideUp();
#                         link_334704298[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="2013553371" href="javascript:toggle_input_2013553371()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2013553371;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2013553371 = document.getElementById("2013553371");
#                 var cell = link_2013553371;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2013553371;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2013553371 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2013553371 = cell.previousElementSibling;
#                 }
#                 input_2013553371.style.display = "none"; // hide
#
#                 toggle_input_2013553371 = function() {
#                     if (input_2013553371.style.display == "none") {
#                         input_2013553371.style.display = ""; // show
#                         link_2013553371.innerHTML = "Hide Input";
#                     } else {
#                         input_2013553371.style.display = "none"; // hide
#                         link_2013553371.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2013553371 = $("a[id='2013553371']");
#                 var cell_2013553371 = link_2013553371.parents("div.cell:first");
#                 if (cell_2013553371.length == 0) {
#                     cell_2013553371 = link_2013553371.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2013553371 = cell_2013553371.children("div.input");
#                 if (input_2013553371.length == 0) {
#                     input_2013553371 = cell_2013553371.prev("div.nbinput");
#                 }
#                 input_2013553371.hide();
#
#                 toggle_input_2013553371 = function() {
#                     if (input_2013553371.is(':hidden')) {
#                         input_2013553371.slideDown();
#                         link_2013553371[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2013553371.slideUp();
#                         link_2013553371[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1490650116" href="javascript:toggle_input_1490650116()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1490650116;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1490650116 = document.getElementById("1490650116");
#                 var cell = link_1490650116;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1490650116;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1490650116 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1490650116 = cell.previousElementSibling;
#                 }
#                 input_1490650116.style.display = "none"; // hide
#
#                 toggle_input_1490650116 = function() {
#                     if (input_1490650116.style.display == "none") {
#                         input_1490650116.style.display = ""; // show
#                         link_1490650116.innerHTML = "Hide Input";
#                     } else {
#                         input_1490650116.style.display = "none"; // hide
#                         link_1490650116.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1490650116 = $("a[id='1490650116']");
#                 var cell_1490650116 = link_1490650116.parents("div.cell:first");
#                 if (cell_1490650116.length == 0) {
#                     cell_1490650116 = link_1490650116.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1490650116 = cell_1490650116.children("div.input");
#                 if (input_1490650116.length == 0) {
#                     input_1490650116 = cell_1490650116.prev("div.nbinput");
#                 }
#                 input_1490650116.hide();
#
#                 toggle_input_1490650116 = function() {
#                     if (input_1490650116.is(':hidden')) {
#                         input_1490650116.slideDown();
#                         link_1490650116[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1490650116.slideUp();
#                         link_1490650116[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1297281546" href="javascript:toggle_input_1297281546()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1297281546;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1297281546 = document.getElementById("1297281546");
#                 var cell = link_1297281546;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1297281546;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1297281546 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1297281546 = cell.previousElementSibling;
#                 }
#                 input_1297281546.style.display = "none"; // hide
#
#                 toggle_input_1297281546 = function() {
#                     if (input_1297281546.style.display == "none") {
#                         input_1297281546.style.display = ""; // show
#                         link_1297281546.innerHTML = "Hide Input";
#                     } else {
#                         input_1297281546.style.display = "none"; // hide
#                         link_1297281546.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1297281546 = $("a[id='1297281546']");
#                 var cell_1297281546 = link_1297281546.parents("div.cell:first");
#                 if (cell_1297281546.length == 0) {
#                     cell_1297281546 = link_1297281546.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1297281546 = cell_1297281546.children("div.input");
#                 if (input_1297281546.length == 0) {
#                     input_1297281546 = cell_1297281546.prev("div.nbinput");
#                 }
#                 input_1297281546.hide();
#
#                 toggle_input_1297281546 = function() {
#                     if (input_1297281546.is(':hidden')) {
#                         input_1297281546.slideDown();
#                         link_1297281546[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1297281546.slideUp();
#                         link_1297281546[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="813321891" href="javascript:toggle_input_813321891()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_813321891;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_813321891 = document.getElementById("813321891");
#                 var cell = link_813321891;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_813321891;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_813321891 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_813321891 = cell.previousElementSibling;
#                 }
#                 input_813321891.style.display = "none"; // hide
#
#                 toggle_input_813321891 = function() {
#                     if (input_813321891.style.display == "none") {
#                         input_813321891.style.display = ""; // show
#                         link_813321891.innerHTML = "Hide Input";
#                     } else {
#                         input_813321891.style.display = "none"; // hide
#                         link_813321891.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_813321891 = $("a[id='813321891']");
#                 var cell_813321891 = link_813321891.parents("div.cell:first");
#                 if (cell_813321891.length == 0) {
#                     cell_813321891 = link_813321891.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_813321891 = cell_813321891.children("div.input");
#                 if (input_813321891.length == 0) {
#                     input_813321891 = cell_813321891.prev("div.nbinput");
#                 }
#                 input_813321891.hide();
#
#                 toggle_input_813321891 = function() {
#                     if (input_813321891.is(':hidden')) {
#                         input_813321891.slideDown();
#                         link_813321891[0].innerHTML = "Hide Input";
#                     } else {
#                         input_813321891.slideUp();
#                         link_813321891[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="1772295030" href="javascript:toggle_input_1772295030()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1772295030;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1772295030 = document.getElementById("1772295030");
#                 var cell = link_1772295030;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1772295030;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1772295030 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1772295030 = cell.previousElementSibling;
#                 }
#                 input_1772295030.style.display = "none"; // hide
#
#                 toggle_input_1772295030 = function() {
#                     if (input_1772295030.style.display == "none") {
#                         input_1772295030.style.display = ""; // show
#                         link_1772295030.innerHTML = "Hide Input";
#                     } else {
#                         input_1772295030.style.display = "none"; // hide
#                         link_1772295030.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1772295030 = $("a[id='1772295030']");
#                 var cell_1772295030 = link_1772295030.parents("div.cell:first");
#                 if (cell_1772295030.length == 0) {
#                     cell_1772295030 = link_1772295030.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1772295030 = cell_1772295030.children("div.input");
#                 if (input_1772295030.length == 0) {
#                     input_1772295030 = cell_1772295030.prev("div.nbinput");
#                 }
#                 input_1772295030.hide();
#
#                 toggle_input_1772295030 = function() {
#                     if (input_1772295030.is(':hidden')) {
#                         input_1772295030.slideDown();
#                         link_1772295030[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1772295030.slideUp();
#                         link_1772295030[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
